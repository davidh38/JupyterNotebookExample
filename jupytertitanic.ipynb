# %%
import pandas as pd
import numpy as np

df = pd.read_excel('titanic3.xls', index_col=None)
df[df['pclass']==2]
# Out:
#      pclass  survived                                               name  \
# 323       2         0                                Abelson, Mr. Samuel
# 324       2         1              Abelson, Mrs. Samuel (Hannah Wizosky)
# 325       2         0                     Aldworth, Mr. Charles Augustus
# 326       2         0                         Andrew, Mr. Edgardo Samuel
# 327       2         0                           Andrew, Mr. Frank Thomas
# 328       2         0                               Angle, Mr. William A
# 329       2         1  Angle, Mrs. William A (Florence "Mary" Agnes H...
# 330       2         0                                    Ashby, Mr. John
# 331       2         0                           Bailey, Mr. Percy Andrew
# 332       2         0                     Baimbrigge, Mr. Charles Robert
# 333       2         1                            Ball, Mrs. (Ada E Hall)
# 334       2         0                      Banfield, Mr. Frederick James
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_excel('titanic3.xls', index_col=None)
df[df['pclass'].isin([1,2])]
# Out:
#      pclass  survived                                               name  \
# 0         1         1                      Allen, Miss. Elisabeth Walton
# 1         1         1                     Allison, Master. Hudson Trevor
# 2         1         0                       Allison, Miss. Helen Loraine
# 3         1         0               Allison, Mr. Hudson Joshua Creighton
# 4         1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5         1         1                                Anderson, Mr. Harry
# 6         1         1                  Andrews, Miss. Kornelia Theodosia
# 7         1         0                             Andrews, Mr. Thomas Jr
# 8         1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9         1         0                            Artagaveytia, Mr. Ramon
# 10        1         0                             Astor, Col. John Jacob
# 11        1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_excel('titanic3.xls', index_col=None)
df[df['pclass'].isin([1,2,3]) & (df['age']<14) & (df['survived']==1)]bi.groupby(['sex']).mean()
#df[df['age']<14].count()['pclass']
# Out:
#           pclass  survived       age     sibsp     parch       fare  body
# sex
# female  2.517241       1.0  4.882186  0.896552  1.241379  22.934483   NaN
# male    2.250000       1.0  4.625000  0.821429  1.357143  43.819939   NaN

# %%
import pandas as pd
import numpy as np

df = pd.read_excel('titanic3.xls', index_col=None)
df[df['pclass'].isin([1,2,3]) & (df['age']<14)].groupby(['sex']).mean()
# Out:
#           pclass  survived       age     sibsp     parch       fare  body
# sex
# female  2.652174  0.630435  5.208335  1.434783  1.369565  26.456611   NaN
# male    2.603774  0.528302  5.416666  1.905660  1.377358  36.843238   2.5

# %%
df[df['pclass'].isin([1,2,3]) & (df['age']<14) & (df['survived']==1)].count()
# Out:
# pclass       57
# survived     57
# name         57
# sex          57
# age          57
# sibsp        57
# parch        57
# ticket       57
# fare         57
# cabin        13
# embarked     57
# boat         57
# body          0
# home.dest    43
# dtype: int64

# %%
df[(df['age']<14) & (df['survived']==0)].count()
# Out:
# pclass       42
# survived     42
# name         42
# sex          42
# age          42
# sibsp        42
# parch        42
# ticket       42
# fare         42
# cabin         2
# embarked     42
# boat          0
# body          2
# home.dest    18
# dtype: int64

# %%
df[df['pclass'].isin([1,2,3]) & (df['age']<14)].mean()
# Out:
# pclass       2.626263
# survived     0.575758
# age          5.319866
# sibsp        1.686869
# parch        1.373737
# fare        32.017128
# body         2.500000
# dtype: float64

# %%
(df[df['pclass'].isin([1,2,3]) & (df['age']<14)].count()[0]/df.count())
# Out:
# 0.07563025210084033

# %%
df.count()[0]
# Out:
# 1309

# %%
df.groupby(['sex','pclass']).mean()
# Out:
#                survived        age     sibsp     parch        fare        body
# sex    pclass
# female 1       0.965278  37.037594  0.555556  0.472222  109.412385         NaN
#        2       0.886792  27.499191  0.500000  0.650943   23.234827   52.000000
#        3       0.490741  22.185307  0.791667  0.731481   15.324250  183.000000
# male   1       0.340782  41.029250  0.340782  0.279330   69.888385  162.828571
#        2       0.146199  30.815401  0.327485  0.192982   19.904946  171.233333
#        3       0.152130  25.962273  0.470588  0.255578   12.415462  151.854167

# %%
df.groupby('survived').count()
# Out:
#           pclass  name  sex  age  sibsp  parch  ticket  fare  cabin  embarked  \
# survived
# 0            809   809  809  619    809    809     809   808    102       809
# 1            500   500  500  427    500    500     500   500    193       498
#
#           boat  body  home.dest
# survived
# 0            9   121        398
# 1          477     0        347

# %%
df.groupby('survived').mean()
# Out:
#             pclass        age     sibsp     parch       fare        body
# survived
# 0         2.500618  30.545369  0.521632  0.328801  23.353831  160.809917
# 1         1.962000  28.918228  0.462000  0.476000  49.361184         NaN

# %%
df.drop(['cabin'], axis=1)
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
df2 = df[['name','pclass','fare']]
df2 = df2[:10]
df.index.values
# Out:
# array([   0,    1,    2, ..., 1306, 1307, 1308])

# %%
pd.crosstab(df.pclass,df.sex, margins=True)
# Out:
# sex     female  male   All
# pclass
# 1          144   179   323
# 2          106   171   277
# 3          216   493   709
# All        466   843  1309
