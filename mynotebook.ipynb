# %%
import pandas as pd
import numpy as np

pd.Series([1,2,3,4,np.nan])
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    NaN
# dtype: float64

# %%
import pandas_datareader.data as web
from talib import RSI, BBANDS
import matplotlib.pyplot as plt
import pandas as pd
#start = '2017-04-22'
#end = '2019-02-19'

#symbol = 'EOD/HD'
#max_holding = 100
#price = web.DataReader(name=symbol, data_source='quandl', start=start, end=end, access_key='tyAEGUMXjiJ5znHs4av6')

#price.to_csv('file1.csv') 

price = pd.read_csv('file1.csv')
#print(price)
print(type(price))
close = price.loc[:, ['Date', 'Adj_Close']].values
print(close)
#print(close)
#up, mid, low = BBANDS(close, timeperiod=20, nbdevup=2, nbdevdn=2, matype=0)

#si = RSI(close, timeperiod=14)
#print("RSI (first 10 elements)\n", rsi[14:24])
print("hi")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# [['2019-02-15' 192.39]
#  ['2019-02-14' 187.71]
#  ['2019-02-13' 188.41]
#  ['2019-02-12' 185.52]
#  ['2019-02-11' 182.92]
#  ['2019-02-08' 184.54]
#  ['2019-02-07' 184.07]
#  ['2019-02-06' 184.72]
#  ['2019-02-05' 186.39]
#  ['2019-02-04' 186.43]
#  ['2019-02-01' 184.37]
#  ['2019-01-31' 183.53]
#  ['2019-01-30' 182.18]
#  ['2019-01-29' 179.69]
#  ['2019-01-28' 179.83]
#  ['2019-01-25' 180.4]
#  ['2019-01-24' 177.29]
#  ['2019-01-23' 176.89]
#  ['2019-01-22' 177.11]
#  ['2019-01-18' 179.58]
#  ['2019-01-17' 174.87]
#  ['2019-01-16' 177.04]
#  ['2019-01-15' 176.47]
#  ['2019-01-14' 178.81]
#  ['2019-01-11' 179.41]
#  ['2019-01-10' 179.06]
#  ['2019-01-09' 179.73]
#  ['2019-01-08' 177.89]
#  ['2019-01-07' 177.04]
#  ['2019-01-04' 173.62]
#  ['2019-01-03' 168.61]
#  ['2019-01-02' 172.41]
#  ['2018-12-31' 171.82]
#  ['2018-12-28' 170.22]
#  ['2018-12-27' 170.32]
#  ['2018-12-26' 168.28]
#  ['2018-12-24' 158.14]
#  ['2018-12-21' 160.48]
# ...
