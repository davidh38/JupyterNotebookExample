# %%
import numpy as np
import pandas as pd
#datetime=pd.DatetimeIndex(['2018-01-01', '2018-01-02','2018-02-02'])
index = pd.date_range(start='2018-01-01', end='2018-01-03')
stocks = { 'close':[13,15,14], 'open':[12,14,13]}
df = pd.DataFrame(stocks, index=datetime)
df.set_index(index)
df2 = df.close.resample('M').mean()

# %%
# %matplotlib inline
df.plot()

# %%
import numpy as np
rng = pd.date_range('2018-01-01', periods=9)
s = pd.Series(np.random.randint(1,10, 9), index=rng)
s
# Out:
# 2018-01-01    8
# 2018-01-02    8
# 2018-01-03    2
# 2018-01-04    9
# 2018-01-05    3
# 2018-01-06    9
# 2018-01-07    5
# 2018-01-08    9
# 2018-01-09    7
# Freq: D, dtype: int64
