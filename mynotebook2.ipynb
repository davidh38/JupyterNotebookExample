# %%
# %matplotlib inline
from pylab import *
x = linspace(0, 5, 10)
y = x ** 8
from pylab import *
figure()
plot(x, y, 'r')
xlabel('x')
ylabel('y')
title('title')
show()

# %% [markdown]
# ### Hello World

# %%
a = 5
print(a)
# Out:
# 5
